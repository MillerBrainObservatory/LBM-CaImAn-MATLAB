# %%
import numpy as np
import tifffile
from pathlib import Path
import h5py
import os
from matplotlib import pyplot as plt
os.getcwd() # if on WSL, /mnt/c/Users is your userpath
# Out:
# '/mnt/c/Users/RBO/repos/LBM_caiman_matlab/notebooks'

# %%
#extracted_3/extracted_plane_1.h5
path = Path("/mnt/c/Users/RBO/Documents/data/high_res/")
files = [x for x in path.glob("*extracted_0/*.h5")]
path = files[0]
f = h5py.File(path, 'r')
# list(f.keys())

# %%
files
# Out:
# [PosixPath('/mnt/c/Users/RBO/Documents/data/high_res/extracted_0')]

# %%
#data = np.array(data).transpose() # loaded in F order -> transpose it

# %%
#data.shape
# Out:
# (600, 538, 1730)

# %%
data = f['Y'][5,:,:]
fig, ax = plt.subplots()
ax.imshow(data)
